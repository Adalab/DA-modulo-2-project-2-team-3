# %%
from PIL import Image

# %% [markdown]
# ## RELACIÓN INDUSTRIA - INVERISÓN EN MACHINE LEARNING

# %%
Image.open('/Users/veronicabellidosanmartin/Desktop/teoria/TEORIA/codigo_personal/proyecto2/uno.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1634x833 at 0x7FE0FD119FA0>

# %% [markdown]
# >**CONCLUSIONES**
# - Podemos observar que aún, generalizado a todas las industrias estudiadas, no se invierte mucho en ML.
# - Aún así, si vemos el crecimiento según el rango de inversión, destacamos la industria Computers/Technology, la cual es la que tiene una gran presencia en todos los rangos. Esta industria es la que más apuesta por esta metodología de trabajo.
# - La industria Accounting/Finance, también invierte bastante en ML, seguido de Academics/Education, la cual no se encuentra de las más destacadas en el rango más elevado, pero sí en los demás.
#
# - Estas tres industrias son las que más nos interesan para conocer si el mercado en el que van a moverse las alumnas una vez finalicen el hipotético BootCamp de Machine Learning está interesado en esta tecnología.
# - La respuesta que deifnimos una vez estudiada la gráfica es positiva para la empresa Adalab, a la hora de formalizar un nuevo curso.

# %% [markdown]
# ## RELACIÓN CURRENT USE OF MACHINE LEARNING - INDUSTRIA

# %%
Image.open('/Users/veronicabellidosanmartin/Desktop/teoria/TEORIA/codigo_personal/proyecto2/dos.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1990x989 at 0x7FE0FD0F6B50>

# %% [markdown]
# >**CONCLUSIONES**
#
# - En general, aplicado a casi todas las industrias, se desconoce cuál es el uso de ML, esto se demuestra en el use que le dan actualmente en las empresas.
#
# - Los sectores tecnológicos y financieros sí tienen un plan establecido de uso y trabajo de esta metodología.
#
# - El sector académico está empezando a navegar por esta tecnología, usando recientemente el ML en sus empresas dentro de la indusria. Esto puede indicar que esta industria puede estar orientándose a la enseñanza de la misma, por lo que puede ser un punto interesante para nuetsra cliente Adalab a la hora de valorar un posible Bootcamp.

# %% [markdown]
# ## RELACIÓN CURRENT USE OF MACHINE LEARNING - MAIN ACTIVITIES AT WORK

# %%
Image.open('/Users/veronicabellidosanmartin/Desktop/teoria/TEORIA/codigo_personal/proyecto2/tres.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2409x1057 at 0x7FE0FCD22640>

# %% [markdown]
# >**CONCLUSIONES**
#
# - De manera genérica, independientemente de la experiencia o el uso que estén dando las diferentes industrias a ML, la actividad más repetida es construir prototipos para ver cómo el ML puede ayudar en diferentes sectores. Buscar una utilidad real para sus propios datos.
#
# - La siguiente actividad sería el análisis de los datos a través del ML, esto se repite sobre todo en aquellas industrias que están explorando los métodos de ML.

# %% [markdown]
# ## RELACIÓN INDUSTRIA - MAIN ACTIVITIES AT WORK

# %%
Image.open('/Users/veronicabellidosanmartin/Desktop/teoria/TEORIA/codigo_personal/proyecto2/cuatro.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1990x989 at 0x7FE0FC476880>

# %% [markdown]
# >**CONCLUSIONES**
#
# *¿Qué tipo de actividades realiza cada industria?*
#
# - Según las grfáficas obtenidas, el uso que se le da al ML es el de crear prototipos para saber cómo puede funcionar el ML en diferentes áreas dentro de las industrias. Esta idea coincide también con las 3 industrias destacadas que pueden aportarnos más información partiendo de nuestro objetivo.
#
# - Analizar y entender la influencia de los datos en los productos o en las decisiones de cada empresa, es el siguiente uso que más se repite en los gráficos.
#
# - Atendiendo a este análisis, podemos observar que esa sería una posible línea de aprendizaje en el supuesto BootCamp sobre ML. Las sesiones diseñadas a aprender de los productos y en la toma de decisiones, así como el análisis de los datos, pudiendo reutilizar materiales del anterior BootCamp de Data Analytics.

# %% [markdown]
# ## RELACIÓN INVERSIÓN - MAIN ACTIVITIES AT WORK

# %%
Image.open('/Users/veronicabellidosanmartin/Desktop/teoria/TEORIA/codigo_personal/proyecto2/cinco.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1643x937 at 0x7FE0FCD60C40>

# %% [markdown]
# >**CONCLUSIONES**
#
# - De nuevo, obervamos que las actividades de construir prototipos y el análisis de los datos a través del ML, son aquellas en las que las empresas invierten más para su desarrollo.
#
# - De todas formas, tenemos muchos datos 'undefined' lo que podemos definir como un gráfico con resultados poco fiables.
