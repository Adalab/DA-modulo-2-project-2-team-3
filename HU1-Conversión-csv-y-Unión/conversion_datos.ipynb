# %%
#Convertimos todos los ficheros a formato pickle para que se conserven todos los tipos de datos contenidos en vcacada fichero.

# %%
import pandas as pd
import numpy as np

# %%
#csv 
    # guardamos en una variable la lectura del DF del archivo csv

df_csv= pd.read_csv('../data/exported_data.csv')
df_csv
# Out:
#        index         Q10_Part_1       Q10_Part_2 Q10_Part_3 Q10_Part_4  \
# 0          0                NaN  Colab Notebooks        NaN        NaN
# 1          1   Kaggle Notebooks  Colab Notebooks        NaN        NaN
# 2          2   Kaggle Notebooks              NaN        NaN        NaN
# 3          3                NaN  Colab Notebooks        NaN        NaN
# 4          4                NaN              NaN        NaN        NaN
# ...      ...                ...              ...        ...        ...
# 25968  25968                NaN  Colab Notebooks        NaN        NaN
# 25969  25969                NaN              NaN        NaN        NaN
# 25970  25970                NaN              NaN        NaN        NaN
# 25971  25971                NaN              NaN        NaN        NaN
# 25972  25972                NaN              NaN        NaN        NaN
#
#       Q10_Part_5 Q10_Part_6 Q10_Part_7                           Q10_Part_8  \
# ...

# %%
# Convertimos el archivo csv a pickle y lo guardamos en otra carpeta para mejor organización

df_csv.to_pickle('../data/archivos_pickle/csv_pickle.pickle')

# %%
# Guardamos la lectura del DF de csv en pickle para su posterior utilización 

df_csv_pickle=pd.read_pickle('../data/archivos_pickle/csv_pickle.pickle')

# %%
#xml

df_xml= pd.read_xml('../data/data_xml_clean.xml')
df_xml.head(1)
# Out:
#    level_0  index  time    age gender
# 0        0      0   910  50-54    Man

# %%
df_xml.to_pickle('../data/archivos_pickle/xml_pickle.pickle')

# %%
df_xml_pickle=pd.read_pickle('../data/archivos_pickle/xml_pickle.pickle')

# %%
#txt

df_txt= pd.read_csv('../data/data_txt_clean.txt',sep=';')
df_txt.head(1)
# Out:
#    index     Q3                 Q4     Q5          Q6      Q8       Q11  \
# 0      0  India  Bachelor’s degree  Other  5-10 years  Python  A laptop
#
#          Q13         Q15                        Q20  ...  \
# 0  2-5 times  5-10 years  Manufacturing/Fabrication  ...
#
#                                                  Q41         Q7            Q9  \
# 0  Local development environments (RStudio, Jupyt...  Python, R   Vim / Emacs
#
#                   Q12                                                Q14  \
# 0  Google Cloud TPUs    Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ...
#
#                                  Q16  \
# 0  Scikit-learn , TensorFlow ,Caret
#
#                                                  Q17  \
# 0  Linear or Logistic Regression, Decision Trees ...
#
#                                                  Q24           Q32    Q34
# 0   None of these activities are an important par...   PostgreSQL    None
#
# [1 rows x 27 columns]

# %%
df_txt.to_pickle('../data/archivos_pickle/txt_pickle.pickle')

# %%
#csv 2.0

df_csv2= pd.read_csv('../data/data_remaning_kaggle.csv')
df_csv2
# Out:
#        Unnamed: 0  index                                         Q18_Part_1  \
# 0               0      0  General purpose image/video tools (PIL, cv2, s...
# 1               1      1                                                NaN
# 2               2      2                                                NaN
# 3               3      3  General purpose image/video tools (PIL, cv2, s...
# 4               4      4                                                NaN
# ...           ...    ...                                                ...
# 25968       25968  25968  General purpose image/video tools (PIL, cv2, s...
# 25969       25969  25969                                                NaN
# 25970       25970  25970                                                NaN
# 25971       25971  25971                                                NaN
# 25972       25972  25972                                                NaN
#
# ...

# %%
df_csv2.to_pickle('../data/archivos_pickle/csv2_pickle.pickle')

# %%
#CONVERTIMOS TODOS A CSV:

# %%
df_txt.to_csv('../data/archivos_csv/txt_csv.csv')

# %%
df_xml.to_csv('../data/archivos_csv/xml_csv.csv')

# %%
df_csv3= pd.read_csv('../data/archivos_csv/txt_csv.csv')
df_csv3
# Out:
#        Unnamed: 0  index                        Q3                 Q4  \
# 0               0      0                     India  Bachelor’s degree
# 1               1      1                 Indonesia    Master’s degree
# 2               2      2                  Pakistan    Master’s degree
# 3               3      3                    Mexico    Doctoral degree
# 4               4      4                     India    Doctoral degree
# ...           ...    ...                       ...                ...
# 25968       25968  25968                     Egypt  Bachelor’s degree
# 25969       25969  25969                     China    Master’s degree
# 25970       25970  25970                    Sweden    Doctoral degree
# 25971       25971  25971  United States of America    Master’s degree
# 25972       25972  25972                     India  Bachelor’s degree
#
#                             Q5                         Q6      Q8  \
# ...

# %%
df_csv4= pd.read_csv('../data/archivos_csv/xml_csv.csv')
df_csv4
# Out:
#        Unnamed: 0  level_0  index  time    age gender
# 0               0        0      0   910  50-54    Man
# 1               1        1      1   784  50-54    Man
# 2               2        2      2   924  22-24    Man
# 3               3        3      3   575  45-49    Man
# 4               4        4      4   781  45-49    Man
# ...           ...      ...    ...   ...    ...    ...
# 25968       25968    25968  25968  1756  30-34    Man
# 25969       25969    25969  25969   253  22-24    Man
# 25970       25970    25970  25970   494  50-54    Man
# 25971       25971    25971  25971   277  45-49    Man
# 25972       25972    25972  25972   255  18-21    Man
#
# [25973 rows x 6 columns]

# %%
#UNIMOS TODOS LOS DF_CSV:

total=df_csv+df_csv2+df_csv3+df_csv4
total
# Out:
#        Q10_OTHER  Q10_Part_1  Q10_Part_10  Q10_Part_11  Q10_Part_12  \
# 0            NaN         NaN          NaN          NaN          NaN
# 1            NaN         NaN          NaN          NaN          NaN
# 2            NaN         NaN          NaN          NaN          NaN
# 3            NaN         NaN          NaN          NaN          NaN
# 4            NaN         NaN          NaN          NaN          NaN
# ...          ...         ...          ...          ...          ...
# 25968        NaN         NaN          NaN          NaN          NaN
# 25969        NaN         NaN          NaN          NaN          NaN
# 25970        NaN         NaN          NaN          NaN          NaN
# 25971        NaN         NaN          NaN          NaN          NaN
# 25972        NaN         NaN          NaN          NaN          NaN
#
#        Q10_Part_13  Q10_Part_14  Q10_Part_15  Q10_Part_16  Q10_Part_2  ...  \
# ...

# %%
total.to_csv('../HU1/total_csv.csv')

# %%
total
# Out:
#        Q10_OTHER  Q10_Part_1  Q10_Part_10  Q10_Part_11  Q10_Part_12  \
# 0            NaN         NaN          NaN          NaN          NaN
# 1            NaN         NaN          NaN          NaN          NaN
# 2            NaN         NaN          NaN          NaN          NaN
# 3            NaN         NaN          NaN          NaN          NaN
# 4            NaN         NaN          NaN          NaN          NaN
# ...          ...         ...          ...          ...          ...
# 25968        NaN         NaN          NaN          NaN          NaN
# 25969        NaN         NaN          NaN          NaN          NaN
# 25970        NaN         NaN          NaN          NaN          NaN
# 25971        NaN         NaN          NaN          NaN          NaN
# 25972        NaN         NaN          NaN          NaN          NaN
#
#        Q10_Part_13  Q10_Part_14  Q10_Part_15  Q10_Part_16  Q10_Part_2  ...  \
# ...

# %%
df_csv
# Out:
#        index         Q10_Part_1       Q10_Part_2 Q10_Part_3 Q10_Part_4  \
# 0          0                NaN  Colab Notebooks        NaN        NaN
# 1          1   Kaggle Notebooks  Colab Notebooks        NaN        NaN
# 2          2   Kaggle Notebooks              NaN        NaN        NaN
# 3          3                NaN  Colab Notebooks        NaN        NaN
# 4          4                NaN              NaN        NaN        NaN
# ...      ...                ...              ...        ...        ...
# 25968  25968                NaN  Colab Notebooks        NaN        NaN
# 25969  25969                NaN              NaN        NaN        NaN
# 25970  25970                NaN              NaN        NaN        NaN
# 25971  25971                NaN              NaN        NaN        NaN
# 25972  25972                NaN              NaN        NaN        NaN
#
#       Q10_Part_5 Q10_Part_6 Q10_Part_7                           Q10_Part_8  \
# ...
