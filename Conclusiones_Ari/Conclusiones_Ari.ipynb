# %%
from PIL import Image

# %% [markdown]
# ## `1.A RELACIÓN EMPLEO(PUESTO DE TRABAJO) Y ML TOOLS EN DOS AÑOS [Q5 Y Q37]`
#
# - ¿Cuál es la herramienta por la que se apuesta (dependiendo del puesto de trabajo), que va a despuntar en 2 años?

# %%
Image.open("C:/Users/arian/Desktop/Imágenes proyectos/uno_a.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1182x857>

# %% [markdown]
# #### `CONCLUSIONES GRÁFICA 1.A`
#
# - Los datos sugieren que las herramientas de ML que más van a despuntar para los siguientes dos años son las de Amazon SageMaker Autopilot y Azure Automated Machine Learning respectivamente.
#
# - También se observa según los datos obtenidos, que serán los estudiantes los que más utilizaran estas herramientas de ML como preferencia para los próximos dos años.
#
# - Por otra parte, el Software Engineer, Machine Learning Engineer, Data Scientist, y Data Analyst también apostarán por Amazon SageMaker Autopilot y Azure Automated Machine Learning respectivamente, y como tercera opción DataRobot AutoML como preferencia a usar para los próximos dos años.

# %% [markdown]
# ## `1.B RELACIÓN EMPLEO(SEGÚN LA COMPENSACIÓN ANUAL) Y ML TOOLS EN DOS AÑOS [Q25 Y Q37]`
#
# - ¿Cuál es la herramienta por la que se apuesta (dependiendo del sueldo), que va a despuntar en 2 años?

# %%
Image.open("/Users/arian/Desktop/Imágenes proyectos/uno_b.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1615x643>

# %% [markdown]
# #### `CONCLUSIONES GRÁFICA 1.B`
#
# - En general vemos que las herramientas de ML mejor pagadas para los próximos dos años serán la de Amazon SageMaker Autopilot, Azure Automated Machine Learning  y Google Cloud AutoML respectivamente.
# - Esto aplica para todos los rangos de sueldos.

# %% [markdown]
# Como conclusión de la unión de las gráficas 1.A Y 1.B, las herrmientas de ML Amazon SageMaker Autopilot, Azure Automated Machine Learning  y Google Cloud AutoML son las que más no interesa conocer por el despunte que se obsrva para los próximos dos años, tanto por la compensación anual que pueda tener, como por los grandes roles de profesionales que las usan.

# %% [markdown]
# ## `2. RELACIÓN CURRENT USE ML Y TAMAÑO DE LA EMPRESA [Q23 Y Q21]`
# ¿Se utilizan métodos de ML en las grandes empresas?

# %%
Image.open("/Users/arian/Desktop/Imágenes proyectos/dos.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1617x672>

# %% [markdown]
# #### `CONCLUSIONES GRÁFICA 2`
#
# - Vemos que los resultados arrojan en general que las empresas No utilizan métodos de ML.
#
# En las que utilizan métodos de ML, los datos sugieren que:
# - En las pequeñas empresas hay tendencia a explorar métodos de ML.
# - En las medianas y grandes empresas tienen métodos de ML bien establecidos.

# %% [markdown]
# ## `3. RELACIÓN TAMAÑO DE LA EMPRESA SEGÚN LA CANTIDAD DE EMPLEADOS E INVERSIÓN EN ML [Q21 Y Q26]`
#
# ¿Cuál es la relación entre la inversión en ML y dependiendo del tamaño de la empresa?

# %%
Image.open("/Users/arian/Desktop/Imágenes proyectos/tres.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1616x662>

# %% [markdown]
# #### `CONCLUSIONES GRÁFICA 3`
#
# - En una visión general, los datos muestran tendencia a que las empresas no invierten mucho dinero en métodos de ML.
# - Dentro de las que más invierten, tenemos a las grandes empresas, es decir, de 1000 empleados en adelante.

# %% [markdown]
# ## `4. AÑOS DE EXPERIENCIA [Q15]`
# ¿Por cuántos años ha utilizado métodos de ML?

# %%
Image.open("/Users/arian/Desktop/Imágenes proyectos/cuatro.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1617x718>

# %% [markdown]
# #### `CONCLUSIONES GRÁFICA 4`
#
# Los datos nos indican en general que el tiempo que llevan trabajando con Métodos de ML es menor a un año con mayor tendencia o un promedio entre 1 y 3 años, lo que demostraría que los diferentes roles profesionales o de estudiantes no tienen muchos años de experiencia empleando métodos de ML.
